# %%
import numpy as np
import pandas as pd
import math
from pydataset import data


import matplotlib.pyplot as plt

# %% [markdown]
# 6. Make a new Jupyter notebook named big_o_notation.ipynb
#     * Title your chart "Big O Notation"
#     * Label your x axis "Elements"
#     * Label your y axis "Operations"
#     * Label your curves or make a legend for the curves
#     * Use LaTex notation where possible
#
#     Curves to graph
#     * y=0n+1and label the curve "O(1)"
#     * y=log(n)and label the curve "O(log n)"
#     * y=nand label the curve "O(n)"
#     * y=n∗log(n)and label it "O(n log n)"
#     * y=n2and label it "O(n^2)"
#     * y=2nand label it "O(2^n)"
#     * y=n!and label it "O(n!)"
#     * y=nnand label it "O(n^n)"

# %%
n = np.array(range(0,20))
y1 = 0 * n + 1
y2 = np.log(n)
y3 = n
y4 = n * np.log(n)
y5 = n**2
y6 = 2**n
y7 = [math.factorial(i) for i in n]
y8 = n**n

plt.figure(figsize=(18,8))
y1_label = '$O(1)$'
y2_label = '$O(log n)$'
y3_label = '$O(n)$'
y4_label = '$O(n log n)$'
y5_label = '$O(n^2)$'
y6_label = '$O(2^n)$'
y7_label = '$O(n!)$'
y8_label = '$O(n^n)$'


plt.plot(n, y1,label = y1_label)
plt.plot(n, y2,label = y2_label)
plt.plot(n, y3,label = y3_label)
plt.plot(n, y4,label = y4_label)
plt.plot(n, y5,label = y5_label)
plt.plot(n, y6,label = y6_label)
plt.plot(n, y7,label = y7_label)
plt.plot(n, y8,label = y8_label)
plt.legend()

#plt.xlim(1,19)
#plt.ylim(0,50)

plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.show()
# Out:
# /var/folders/6c/7ht5b3716k32pz2lmh_pzp8m0000gp/T/ipykernel_10387/2352454179.py:3: RuntimeWarning: divide by zero encountered in log
#   y2 = np.log(n)
# /var/folders/6c/7ht5b3716k32pz2lmh_pzp8m0000gp/T/ipykernel_10387/2352454179.py:5: RuntimeWarning: divide by zero encountered in log
#   y4 = n * np.log(n)
# /var/folders/6c/7ht5b3716k32pz2lmh_pzp8m0000gp/T/ipykernel_10387/2352454179.py:5: RuntimeWarning: invalid value encountered in multiply
#   y4 = n * np.log(n)

# %%
plt.plot({10,20})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 plt.plot({10,20})
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# ...
