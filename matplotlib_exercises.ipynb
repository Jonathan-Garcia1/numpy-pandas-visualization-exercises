# %%
import numpy as np
import pandas as pd
import math
from pydataset import data


import matplotlib.pyplot as plt

# %% [markdown]
# 1. Use matplotlib to plot the following equation:y=x2−x+2You'll need to write the code that generates the x and y points.Add an anotation for the point 0, 0, the origin.

# %%
x = np.linspace(-10, 11)
y = x**2 - x + 2
plt.annotate('The Origin', xy=(-1, 8))

plt.plot(x, y)

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#     * y=√x
#     * y=2x
#     * y=x3
#     * y=1/(x+1)

# %%
x = np.linspace(-5, 5)
y1 = np.sqrt(x)
y2 = x**3
y3 = 2 * x
y4 = 1 / (x + 1)


plt.plot(x, y1)
plt.show()
# Out:
# /var/folders/6c/7ht5b3716k32pz2lmh_pzp8m0000gp/T/ipykernel_9945/2049417942.py:2: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(x)

# %%
plt.plot(x, y2)
plt.show()

# %%
plt.plot(x, y3)
plt.show()

# %%
plt.plot(x, y4)
plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize = (14, 14))

#Define my first subplot
plt.subplot(2, 2, 1)
plt.plot(x, y1)
# plt.ylim(200, 500)
# plt.title('Slow Steve')

#Define my second subplot
plt.subplot(2, 2, 2)
plt.plot(x, y2)
# plt.ylim(200, 500)
# plt.title('Fast Freddy')

#Define my first subplot
plt.subplot(2, 2, 3)
plt.plot(x, y3)
# plt.ylim(200, 500)
# plt.title('Slow Steve')

#Define my second subplot
plt.subplot(2, 2, 4)
plt.plot(x, y4)
# plt.ylim(200, 500)
# plt.title('Fast Freddy')

plt.tight_layout()

# %% [markdown]
# 5. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
y1_label = '$y = \sqrt{x}$'
y2_label = '$y = x^3$'
y3_label = '$y = 2^x$'
y4_label = '$y = 1/(x + 1)$'
 
plt.plot(x, y1,label = y1_label)
plt.plot(x, y2,label = y2_label)
plt.plot(x, y3,label = y3_label)
plt.plot(x, y4,label = y4_label)
plt.legend()
plt.show()

# %% [markdown]
# 8. Bonus Write the code necessary to write your name on a chart. Use box letters.
# 9. Bonus: use curves for letters in your name that have curves in them.
